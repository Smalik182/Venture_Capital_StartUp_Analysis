# %% [markdown]
# # Venture Captial Analysis
#
# We will be working on a dataset that contains information on nearly 22,000 different start ups.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %matplotlib inline

vc_data = pd.read_csv('Dataset.csv')

# Since the dataset is long, we want to be able to see all column names
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

vc_data.head()
# Out:
#   Organization Name                              Organization Name URL  \
# 0             Nexar    https://www.crunchbase.com/organization/nexar-2
# 1           Medable  https://www.crunchbase.com/organization/medabl...
# 2          Instabox   https://www.crunchbase.com/organization/instabox
# 3           Triller    https://www.crunchbase.com/organization/triller
# 4           OPSkins    https://www.crunchbase.com/organization/opskins
#
#                      Headquarters Location  \
# 0               Tel Aviv, Tel Aviv, Israel
# 1     Palo Alto, California, United States
# 2       HÃ¤gersten, Stockholms Lan, Sweden
# 3        New York, New York, United States
# 4  Santa Monica, California, United States
#
#                                           Industries  \
# 0  Apps, Autonomous Vehicles, Internet, Sensor, T...
# 1  Developer APIs, Health Care, Medical, Medical ...
# 2       Logistics, Shipping, Supply Chain Management
# 3               Digital Media, Music, Social Network
# 4                       E-Commerce, Gaming, Internet
#
#           Last Funding Type Last Funding Date  Last Funding Amount  \
# 0                  Series C         4/30/2020           52000000.0
# 1  Venture - Series Unknown          5/4/2020           25000000.0
# 2            Debt Financing          4/8/2020           23000000.0
# 3                  Series B        10/23/2019           28000000.0
# 4     Initial Coin Offering        11/13/2017           41000000.0
#
#   Last Funding Amount Currency  Last Funding Amount Currency (in USD)  \
# 0                          USD                             52000000.0
# 1                          USD                             25000000.0
# 2                          EUR                             24978252.0
# 3                          USD                             28000000.0
# 4                          USD                             41000000.0
#
#   Number of Employees  Total Funding Amount Total Funding Amount Currency  \
# 0             101-250            96500000.0                           USD
# 1             101-250            33202069.0                           USD
# 2             101-250            47057093.0                           USD
# 3              Nov-50            37500000.0                           USD
# 4              Nov-50            41000000.0                           USD
#
#    Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 0                              96500000.0                       4.0
# 1                              33202069.0                       3.0
# 2                              47057093.0                       5.0
# 3                              37500000.0                       4.0
# 4                              41000000.0                       1.0
#
#   Acquisition Status Acquired by Acquired by URL  Number of Acquisitions  \
# 0                NaN         NaN             NaN                     NaN
# 1                NaN         NaN             NaN                     NaN
# 2                NaN         NaN             NaN                     NaN
# 3                NaN         NaN             NaN                     NaN
# 4                NaN         NaN             NaN                     NaN
#
#    Acquisition Price Currency (in USD)  Number of Founders  Unnamed: 20  \
# 0                                  NaN                 2.0          NaN
# 1                                  NaN                 3.0          NaN
# 2                                  NaN                 3.0          NaN
# 3                                  NaN                 2.0          NaN
# 4                                  NaN                 3.0          NaN
#
#    Acquisition Price Price Currency Company Type Founded Date  \
# 0                NaN            NaN   For Profit     1/1/2015
# 1                NaN            NaN   For Profit     1/1/2015
# 2                NaN            NaN   For Profit     1/1/2015
# 3                NaN            NaN   For Profit     1/1/2015
# 4                NaN            NaN   For Profit     1/1/2015
#
#                          Twitter                              Facebook  \
# 0    http://twitter.com/getnexar         https://facebook.com/getnexar
# 1  http://twitter.com/MedableInc  https://www.facebook.com/MedableInc/
# 2                            NaN  https://www.facebook.com/instabox.se
# 3    https://twitter.com/triller  https://www.facebook.com/trillervids
# 4  https://twitter.com/opskinsgo      https://www.facebook.com/opskins
#
#                                             LinkedIn       Funding Status  \
# 0          https://www.linkedin.com/company/10460529   Late Stage Venture
# 1     https://www.linkedin.com/company/medable-inc-/                  NaN
# 2      https://www.linkedin.com/company/instabox-ab/                  NaN
# 3           https://www.linkedin.com/company/triller  Early Stage Venture
# 4  https://www.linkedin.com/company/opskins-com--...                  NaN
#
#   Acquisition Type Announced Date Estimated Revenue Range
# 0              NaN            NaN           Less than $1M
# 1              NaN            NaN           Less than $1M
# 2              NaN            NaN           Less than $1M
# 3              NaN            NaN           Less than $1M
# 4              NaN            NaN           Less than $1M

# %% [markdown]
# # Data Cleaning
#
# Lets get rid of unnecessary columns first.
# We do not need URL's for the startups so we can first get rid of those.
# We can also remove all the column with data that is not in USD, since there are columns with the conversion to USD.

# %%
vc_data = vc_data.drop(['Organization Name URL', 'Acquired by URL','Twitter','Facebook','LinkedIn',
                       'Total Funding Amount', 'Total Funding Amount Currency',
                       'Acquisition Price', 'Price Currency', 'Unnamed: 20',
                       'Last Funding Amount Currency'], axis = 1)
vc_data.head(2)
# Out:
#   Organization Name                 Headquarters Location  \
# 0             Nexar            Tel Aviv, Tel Aviv, Israel
# 1           Medable  Palo Alto, California, United States
#
#                                           Industries  \
# 0  Apps, Autonomous Vehicles, Internet, Sensor, T...
# 1  Developer APIs, Health Care, Medical, Medical ...
#
#           Last Funding Type Last Funding Date  Last Funding Amount  \
# 0                  Series C         4/30/2020           52000000.0
# 1  Venture - Series Unknown          5/4/2020           25000000.0
#
#    Last Funding Amount Currency (in USD) Number of Employees  \
# 0                             52000000.0             101-250
# 1                             25000000.0             101-250
#
#    Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 0                              96500000.0                       4.0
# 1                              33202069.0                       3.0
#
#   Acquisition Status Acquired by  Number of Acquisitions  \
# 0                NaN         NaN                     NaN
# 1                NaN         NaN                     NaN
#
#    Acquisition Price Currency (in USD)  Number of Founders Company Type  \
# 0                                  NaN                 2.0   For Profit
# 1                                  NaN                 3.0   For Profit
#
#   Founded Date      Funding Status Acquisition Type Announced Date  \
# 0     1/1/2015  Late Stage Venture              NaN            NaN
# 1     1/1/2015                 NaN              NaN            NaN
#
#   Estimated Revenue Range
# 0           Less than $1M
# 1           Less than $1M

# %% [markdown]
# Now lets get a better idea of the data types within this data set

# %%
vc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21528 entries, 0 to 21527
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Organization Name                       21528 non-null  object
#  1   Headquarters Location                   19548 non-null  object
#  2   Industries                              21360 non-null  object
#  3   Last Funding Type                       12473 non-null  object
#  4   Last Funding Date                       12473 non-null  object
#  5   Last Funding Amount                     9924 non-null   float64
#  6   Last Funding Amount Currency (in USD)   9924 non-null   float64
#  7   Number of Employees                     19980 non-null  object
#  8   Total Funding Amount Currency (in USD)  11038 non-null  float64
#  9   Number of Funding Rounds                12473 non-null  float64
#  10  Acquisition Status                      1066 non-null   object
#  11  Acquired by                             364 non-null    object
#  12  Number of Acquisitions                  731 non-null    float64
#  13  Acquisition Price Currency (in USD)     53 non-null     float64
#  14  Number of Founders                      16119 non-null  float64
#  15  Company Type                            16465 non-null  object
#  16  Founded Date                            21528 non-null  object
#  17  Funding Status                          9939 non-null   object
#  18  Acquisition Type                        354 non-null    object
#  19  Announced Date                          364 non-null    object
#  20  Estimated Revenue Range                 21528 non-null  object
# dtypes: float64(7), object(14)
# memory usage: 3.4+ MB

# %% [markdown]
# ### Date Columns
#
# We can see that some of the column contain dates but are of object data type. Lets adjust those to DateTime Objects.

# %%
vc_data["Last Funding Date"] = pd.to_datetime(vc_data['Last Funding Date'], format='%m/%d/%Y')
vc_data["Founded Date"] = pd.to_datetime(vc_data['Founded Date'], format='%m/%d/%Y')
vc_data["Announced Date"] = pd.to_datetime(vc_data['Announced Date'], format='%m/%d/%Y')
vc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21528 entries, 0 to 21527
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Organization Name                       21528 non-null  object
#  1   Headquarters Location                   19548 non-null  object
#  2   Industries                              21360 non-null  object
#  3   Last Funding Type                       12473 non-null  object
#  4   Last Funding Date                       12473 non-null  datetime64[ns]
#  5   Last Funding Amount                     9924 non-null   float64
#  6   Last Funding Amount Currency (in USD)   9924 non-null   float64
#  7   Number of Employees                     19980 non-null  object
#  8   Total Funding Amount Currency (in USD)  11038 non-null  float64
#  9   Number of Funding Rounds                12473 non-null  float64
#  10  Acquisition Status                      1066 non-null   object
#  11  Acquired by                             364 non-null    object
#  12  Number of Acquisitions                  731 non-null    float64
#  13  Acquisition Price Currency (in USD)     53 non-null     float64
#  14  Number of Founders                      16119 non-null  float64
#  15  Company Type                            16465 non-null  object
#  16  Founded Date                            21528 non-null  datetime64[ns]
#  17  Funding Status                          9939 non-null   object
#  18  Acquisition Type                        354 non-null    object
#  19  Announced Date                          364 non-null    datetime64[ns]
#  20  Estimated Revenue Range                 21528 non-null  object
# dtypes: datetime64[ns](3), float64(7), object(11)
# memory usage: 3.4+ MB

# %% [markdown]
# ### Number of Employee column
#
# We can see an error in the dataset where in some rows the Number of Employees is 'Nov-50' or '10-Jan'.
# Lets also clean up the '$' and any newlines we may have (\n)

# %%
clean_data = vc_data.replace({'Nov-50': np.nan, '10-Jan': np.nan, '\$' : '', '\n' : ''}) 

clean_data.head()
# Out:
#   Organization Name                    Headquarters Location  \
# 0             Nexar               Tel Aviv, Tel Aviv, Israel
# 1           Medable     Palo Alto, California, United States
# 2          Instabox       HÃ¤gersten, Stockholms Lan, Sweden
# 3           Triller        New York, New York, United States
# 4           OPSkins  Santa Monica, California, United States
#
#                                           Industries  \
# 0  Apps, Autonomous Vehicles, Internet, Sensor, T...
# 1  Developer APIs, Health Care, Medical, Medical ...
# 2       Logistics, Shipping, Supply Chain Management
# 3               Digital Media, Music, Social Network
# 4                       E-Commerce, Gaming, Internet
#
#           Last Funding Type Last Funding Date  Last Funding Amount  \
# 0                  Series C        2020-04-30           52000000.0
# 1  Venture - Series Unknown        2020-05-04           25000000.0
# 2            Debt Financing        2020-04-08           23000000.0
# 3                  Series B        2019-10-23           28000000.0
# 4     Initial Coin Offering        2017-11-13           41000000.0
#
#    Last Funding Amount Currency (in USD) Number of Employees  \
# 0                             52000000.0             101-250
# 1                             25000000.0             101-250
# 2                             24978252.0             101-250
# 3                             28000000.0                 NaN
# 4                             41000000.0                 NaN
#
#    Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 0                              96500000.0                       4.0
# 1                              33202069.0                       3.0
# 2                              47057093.0                       5.0
# 3                              37500000.0                       4.0
# 4                              41000000.0                       1.0
#
#   Acquisition Status Acquired by  Number of Acquisitions  \
# 0                NaN         NaN                     NaN
# 1                NaN         NaN                     NaN
# 2                NaN         NaN                     NaN
# 3                NaN         NaN                     NaN
# 4                NaN         NaN                     NaN
#
#    Acquisition Price Currency (in USD)  Number of Founders Company Type  \
# 0                                  NaN                 2.0   For Profit
# 1                                  NaN                 3.0   For Profit
# 2                                  NaN                 3.0   For Profit
# 3                                  NaN                 2.0   For Profit
# 4                                  NaN                 3.0   For Profit
#
#   Founded Date       Funding Status Acquisition Type Announced Date  \
# 0   2015-01-01   Late Stage Venture              NaN            NaT
# 1   2015-01-01                  NaN              NaN            NaT
# 2   2015-01-01                  NaN              NaN            NaT
# 3   2015-01-01  Early Stage Venture              NaN            NaT
# 4   2015-01-01                  NaN              NaN            NaT
#
#   Estimated Revenue Range
# 0           Less than $1M
# 1           Less than $1M
# 2           Less than $1M
# 3           Less than $1M
# 4           Less than $1M

# %% [markdown]
# # Filtering the dataset

# %% [markdown]
# ### Filtering by Industries
#
# We can create a funtion that will alow the user to input multiple industries, the function will then run through the dataset and return all rows containing the users chosen industries.

# %%
## This function gets the user's industries
def user_Industries():
    num_of_industries = int(input('How many industries would you like to filter by?\n'))
    list_industries = []
   
    i = 0
    #while i < num_of_industries:
    for i in range(num_of_industries):
        industry = input("Enter the industry:\n")
        i += 1
        
        list_industries.append(industry)

    return list_industries

## We call the fuction here to store the input
a = user_Industries()



## We convert the list into a string
pattern = ', '.join(a)


## Here we are filtering the pattern through the rows of the column
def filter_Industries():
    mask = clean_data['Industries'].str.contains(pattern , case=False, na=False)
    final = clean_data[mask]
    return final

## Function Call
b =  filter_Industries()   

b.head(5)
# Out:
# How many industries would you like to filter by?
# 2
# Enter the industry:
# Apps
# Enter the industry:
# Internet
#            Organization Name                Headquarters Location  \
# 832                   Cymbal    Brooklyn, New York, United States
# 837                  Tingbot      London, England, United Kingdom
# 883   Railroad Project, Inc.  Miami Beach, Florida, United States
# 937                   Wantoo  Vancouver, British Columbia, Canada
# 1810           Threshold 360        Tampa, Florida, United States
#
#                                              Industries  \
# 832                               Apps, Internet, Music
# 837                            Apps, Internet, Software
# 883   Apps, Internet, Real Time, Video, Video Chat, ...
# 937                            Apps, Internet, Software
# 1810            Apps, Internet, Internet of Things, iOS
#
#              Last Funding Type Last Funding Date  Last Funding Amount  \
# 832                       Seed        2015-06-01             250000.0
# 837       Product Crowdfunding        2015-11-02           43261000.0
# 883                       Seed        2015-06-01             345000.0
# 937                       Seed        2015-11-10             500000.0
# 1810  Venture - Series Unknown        2018-02-20            1800008.0
#
#       Last Funding Amount Currency (in USD) Number of Employees  \
# 832                                250000.0                 NaN
# 837                              47642489.0                 NaN
# 883                                345000.0                 NaN
# 937                                500000.0                 NaN
# 1810                              1800008.0                 NaN
#
#       Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 832                                 250000.0                       1.0
# 837                               47642489.0                       1.0
# 883                                 345000.0                       1.0
# 937                                 500000.0                       1.0
# 1810                               2300008.0                       2.0
#
#      Acquisition Status Acquired by  Number of Acquisitions  \
# 832                 NaN         NaN                     NaN
# 837                 NaN         NaN                     NaN
# 883                 NaN         NaN                     NaN
# 937                 NaN         NaN                     NaN
# 1810                NaN         NaN                     NaN
#
#       Acquisition Price Currency (in USD)  Number of Founders Company Type  \
# 832                                   NaN                 3.0   For Profit
# 837                                   NaN                 NaN   For Profit
# 883                                   NaN                 3.0   For Profit
# 937                                   NaN                 NaN   For Profit
# 1810                                  NaN                 1.0   For Profit
#
#      Founded Date Funding Status Acquisition Type Announced Date  \
# 832    2015-01-01           Seed              NaN            NaT
# 837    2015-01-01            NaN              NaN            NaT
# 883    2015-01-01           Seed              NaN            NaT
# 937    2015-01-01           Seed              NaN            NaT
# 1810   2015-01-01            NaN              NaN            NaT
#
#      Estimated Revenue Range
# 832            Less than $1M
# 837            Less than $1M
# 883            Less than $1M
# 937            Less than $1M
# 1810          $1mil - $10mil

# %% [markdown]
# ### Filtering if Company was Acquired
#
# We can pull all startups into a seperate dataframe if the company has already been acquired.

# %%
def filter_if_Acquired():
    mask = clean_data['Acquisition Status'].str.contains('Was Acquired' , case=False, na=False)
    final = clean_data[mask]
    return final

startup_Was_Acquired = filter_Industries()
startup_Was_Acquired.head(5)
# Out:
#            Organization Name                Headquarters Location  \
# 832                   Cymbal    Brooklyn, New York, United States
# 837                  Tingbot      London, England, United Kingdom
# 883   Railroad Project, Inc.  Miami Beach, Florida, United States
# 937                   Wantoo  Vancouver, British Columbia, Canada
# 1810           Threshold 360        Tampa, Florida, United States
#
#                                              Industries  \
# 832                               Apps, Internet, Music
# 837                            Apps, Internet, Software
# 883   Apps, Internet, Real Time, Video, Video Chat, ...
# 937                            Apps, Internet, Software
# 1810            Apps, Internet, Internet of Things, iOS
#
#              Last Funding Type Last Funding Date  Last Funding Amount  \
# 832                       Seed        2015-06-01             250000.0
# 837       Product Crowdfunding        2015-11-02           43261000.0
# 883                       Seed        2015-06-01             345000.0
# 937                       Seed        2015-11-10             500000.0
# 1810  Venture - Series Unknown        2018-02-20            1800008.0
#
#       Last Funding Amount Currency (in USD) Number of Employees  \
# 832                                250000.0                 NaN
# 837                              47642489.0                 NaN
# 883                                345000.0                 NaN
# 937                                500000.0                 NaN
# 1810                              1800008.0                 NaN
#
#       Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 832                                 250000.0                       1.0
# 837                               47642489.0                       1.0
# 883                                 345000.0                       1.0
# 937                                 500000.0                       1.0
# 1810                               2300008.0                       2.0
#
#      Acquisition Status Acquired by  Number of Acquisitions  \
# 832                 NaN         NaN                     NaN
# 837                 NaN         NaN                     NaN
# 883                 NaN         NaN                     NaN
# 937                 NaN         NaN                     NaN
# 1810                NaN         NaN                     NaN
#
#       Acquisition Price Currency (in USD)  Number of Founders Company Type  \
# 832                                   NaN                 3.0   For Profit
# 837                                   NaN                 NaN   For Profit
# 883                                   NaN                 3.0   For Profit
# 937                                   NaN                 NaN   For Profit
# 1810                                  NaN                 1.0   For Profit
#
#      Founded Date Funding Status Acquisition Type Announced Date  \
# 832    2015-01-01           Seed              NaN            NaT
# 837    2015-01-01            NaN              NaN            NaT
# 883    2015-01-01           Seed              NaN            NaT
# 937    2015-01-01           Seed              NaN            NaT
# 1810   2015-01-01            NaN              NaN            NaT
#
#      Estimated Revenue Range
# 832            Less than $1M
# 837            Less than $1M
# 883            Less than $1M
# 937            Less than $1M
# 1810          $1mil - $10mil

# %% [markdown]
# ### Filtering if Company has Acquired other companies
#
# We can pull all startups into a seperate dataframe if the company has acquired other companies.

# %%
def Acquired_others():
    mask = clean_data['Acquisition Status'].str.contains('Made Acquisitions' , case=False, na=False)
    final = clean_data[mask]
    return final

startup_Acquired_Others = filter_Industries()
startup_Acquired_Others.head(5)
# Out:
#            Organization Name                Headquarters Location  \
# 832                   Cymbal    Brooklyn, New York, United States
# 837                  Tingbot      London, England, United Kingdom
# 883   Railroad Project, Inc.  Miami Beach, Florida, United States
# 937                   Wantoo  Vancouver, British Columbia, Canada
# 1810           Threshold 360        Tampa, Florida, United States
#
#                                              Industries  \
# 832                               Apps, Internet, Music
# 837                            Apps, Internet, Software
# 883   Apps, Internet, Real Time, Video, Video Chat, ...
# 937                            Apps, Internet, Software
# 1810            Apps, Internet, Internet of Things, iOS
#
#              Last Funding Type Last Funding Date  Last Funding Amount  \
# 832                       Seed        2015-06-01             250000.0
# 837       Product Crowdfunding        2015-11-02           43261000.0
# 883                       Seed        2015-06-01             345000.0
# 937                       Seed        2015-11-10             500000.0
# 1810  Venture - Series Unknown        2018-02-20            1800008.0
#
#       Last Funding Amount Currency (in USD) Number of Employees  \
# 832                                250000.0                 NaN
# 837                              47642489.0                 NaN
# 883                                345000.0                 NaN
# 937                                500000.0                 NaN
# 1810                              1800008.0                 NaN
#
#       Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 832                                 250000.0                       1.0
# 837                               47642489.0                       1.0
# 883                                 345000.0                       1.0
# 937                                 500000.0                       1.0
# 1810                               2300008.0                       2.0
#
#      Acquisition Status Acquired by  Number of Acquisitions  \
# 832                 NaN         NaN                     NaN
# 837                 NaN         NaN                     NaN
# 883                 NaN         NaN                     NaN
# 937                 NaN         NaN                     NaN
# 1810                NaN         NaN                     NaN
#
#       Acquisition Price Currency (in USD)  Number of Founders Company Type  \
# 832                                   NaN                 3.0   For Profit
# 837                                   NaN                 NaN   For Profit
# 883                                   NaN                 3.0   For Profit
# 937                                   NaN                 NaN   For Profit
# 1810                                  NaN                 1.0   For Profit
#
#      Founded Date Funding Status Acquisition Type Announced Date  \
# 832    2015-01-01           Seed              NaN            NaT
# 837    2015-01-01            NaN              NaN            NaT
# 883    2015-01-01           Seed              NaN            NaT
# 937    2015-01-01           Seed              NaN            NaT
# 1810   2015-01-01            NaN              NaN            NaT
#
#      Estimated Revenue Range
# 832            Less than $1M
# 837            Less than $1M
# 883            Less than $1M
# 937            Less than $1M
# 1810          $1mil - $10mil

# %% [markdown]
# # Insights
#
# Now lets begin on what insights we can get from this dataset.

# %% [markdown]
# ### Generally, how many founders does a start up have?
#
# We can get a clearer picture of how many founders a startup has.
# But first we need to get rid of rows where the number of founders is not available or is 0.

# %%
# First we can replace all values that were empty win NaN using np.nan
clean_data['Number of Founders'].replace('', np.nan, inplace=True)
# Then we drop all values in the specified column using .dropna()
clean_num_founders = cleaned_data.dropna(subset=['Number of Founders'])

# Now we can address where the Number of Founders = 0
final_num_founders = clean_num_founders[clean_num_founders['Number of Founders'] != 0]

final_num_founders.head(5)
# Out:
#   Organization Name                    Headquarters Location  \
# 0             Nexar               Tel Aviv, Tel Aviv, Israel
# 1           Medable     Palo Alto, California, United States
# 2          Instabox       HÃ¤gersten, Stockholms Lan, Sweden
# 3           Triller        New York, New York, United States
# 4           OPSkins  Santa Monica, California, United States
#
#                                           Industries  \
# 0  Apps, Autonomous Vehicles, Internet, Sensor, T...
# 1  Developer APIs, Health Care, Medical, Medical ...
# 2       Logistics, Shipping, Supply Chain Management
# 3               Digital Media, Music, Social Network
# 4                       E-Commerce, Gaming, Internet
#
#           Last Funding Type Last Funding Date  Last Funding Amount  \
# 0                  Series C        2020-04-30           52000000.0
# 1  Venture - Series Unknown        2020-05-04           25000000.0
# 2            Debt Financing        2020-04-08           23000000.0
# 3                  Series B        2019-10-23           28000000.0
# 4     Initial Coin Offering        2017-11-13           41000000.0
#
#   Last Funding Amount Currency  Last Funding Amount Currency (in USD)  \
# 0                          USD                             52000000.0
# 1                          USD                             25000000.0
# 2                          EUR                             24978252.0
# 3                          USD                             28000000.0
# 4                          USD                             41000000.0
#
#   Number of Employees  Total Funding Amount Currency (in USD)  \
# 0             101-250                              96500000.0
# 1             101-250                              33202069.0
# 2             101-250                              47057093.0
# 3                 NaN                              37500000.0
# 4                 NaN                              41000000.0
#
#    Number of Funding Rounds Acquisition Status Acquired by  \
# 0                       4.0                NaN         NaN
# 1                       3.0                NaN         NaN
# 2                       5.0                NaN         NaN
# 3                       4.0                NaN         NaN
# 4                       1.0                NaN         NaN
#
#    Number of Acquisitions  Acquisition Price Currency (in USD)  \
# 0                     NaN                                  NaN
# 1                     NaN                                  NaN
# 2                     NaN                                  NaN
# 3                     NaN                                  NaN
# 4                     NaN                                  NaN
#
#    Number of Founders Company Type Founded Date       Funding Status  \
# 0                 2.0   For Profit   2015-01-01   Late Stage Venture
# 1                 3.0   For Profit   2015-01-01                  NaN
# 2                 3.0   For Profit   2015-01-01                  NaN
# 3                 2.0   For Profit   2015-01-01  Early Stage Venture
# 4                 3.0   For Profit   2015-01-01                  NaN
#
#   Acquisition Type Announced Date Estimated Revenue Range
# 0              NaN            NaT            Less than 1M
# 1              NaN            NaT            Less than 1M
# 2              NaN            NaT            Less than 1M
# 3              NaN            NaT            Less than 1M
# 4              NaN            NaT            Less than 1M

# %%
plt.style.use('fivethirtyeight')
num_of_founders = final_num_founders['Number of Founders'].value_counts()
plt.figure(figsize=(7, 6))
ax = num_of_founders.plot(kind='bar', rot=0, color="b")
ax.set_title("Bar Graph of Number of Founders", y = 1)
ax.set_xlabel('Number of Founders')
ax.set_ylabel('Frequency')
#ax.set_xticklabels(('Male', 'Female'))

for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2
    space = 1
    label = "{:.0f}".format(y_value)
    ax.annotate(label, (x_value, y_value), xytext=(0, space), textcoords="offset points", ha='center', va='bottom')
plt.show()

# %% [markdown]
# ### Potential seed startups making revenue greater than $10M
#
# Lets see if there are any start ups that are still in their early stages but are making decent revenue.
#
# First we will filter for all start ups whos last funding round was a seed round.
# Than we can filter for the Estimated Revenue Range to be $10M to $50M.
#
# Further more we can apply our industry filter fucntion to try and zone in on potential start ups within certain industries.
#
# So lets try to find a startup that has only had a seed round of funding, is making between $10m to 50m in revenue and is working in the blockchain space.

# %%
# Filtering for seed as last funding round 
def seed_revenue():
    mask = cleaned_data['Last Funding Type'].str.contains('Seed' , case=False, na=False)
    final = cleaned_data[mask]                                                   
    return final


# Filtering for $10 to $50M Revenue startups    
def high_revenue():
    mask = seed_df['Estimated Revenue Range'].str.contains('10M to 50M' , case=False, na=False)
    final = seed_df[mask]                                                     
    return final

## This function gets the user's industries
def user_industry2():
    num_of_industries = int(input('How many industries would you like to filter by?\n'))
    list_industries = []
   
    i = 0
    #while i < num_of_industries:
    for i in range(num_of_industries):
        industry = input("Enter the industry:\n")
        i += 1
        
        list_industries.append(industry)

    return list_industries


# We can run our user_industries() here and convert it into a pattern
c = user_industry2()
pattern = ', '.join(c)

## Here we are filtering the pattern through the rows of the column
def filter_Industries():
    mask = highRev['Industries'].str.contains(pattern , case=False, na=False)
    final = highRev[mask]
    return final




# Here we do our Function Call
seed_df = seed_revenue()
highRev = high_revenue()
potential_startup = filter_Industries()

# This gives us our blockchain startups.
potential_startup.head(100)
# Out:
# How many industries would you like to filter by?
# 1
# Enter the industry:
# Blockchain
#       Organization Name                     Headquarters Location  \
# 2046              Civic  San Francisco, California, United States
# 2194             Nickel      Singapore, Central Region, Singapore
# 4295       R TECH Group           Cumming, Georgia, United States
# 13081            Hoopox                   Beijing, Beijing, China
# 13314           Jointer  San Francisco, California, United States
# 14693         FXCH Ltd.                   Dublin, Dublin, Ireland
# 15129               VIA  Somerville, Massachusetts, United States
# 16175            LuxTag      Kuala Lumpur, Kuala Lumpur, Malaysia
# 19236           Arweave           London, England, United Kingdom
# 19591    Transship Corp          Chicago, Illinois, United States
# 20368       Superblocks         Stockholm, Stockholms Lan, Sweden
# 20861         Aximetria                     Zug, Zug, Switzerland
#
#                                               Industries Last Funding Type  \
# 2046                     Blockchain, Identity Management              Seed
# 2194   Blockchain, Financial Exchanges, Financial Ser...              Seed
# 4295   Blockchain, Internet of Things, Telecommunicat...              Seed
# 13081  Blockchain, Information Services, Network Hard...              Seed
# 13314  Artificial Intelligence, Blockchain, Commercia...              Seed
# 14693           Blockchain, Financial Services, Internet              Seed
# 15129  Analytics, Artificial Intelligence, Blockchain...              Seed
# 16175  Big Data, Blockchain, Information Services, In...              Seed
# 19236  Blockchain, Cryptocurrency, Data Storage, Info...              Seed
# 19591  Blockchain, Information Technology, Logistics,...              Seed
# 20368                     Blockchain, Ethereum, Internet              Seed
# 20861  Banking, Bitcoin, Blockchain, Financial Servic...              Seed
#
#       Last Funding Date  Last Funding Amount Last Funding Amount Currency  \
# 2046         2017-09-21                  NaN                          NaN
# 2194         2016-05-03              30000.0                          SGD
# 4295         2016-03-20                  NaN                          NaN
# 13081        2017-09-20           28000000.0                          CNY
# 13314        2019-02-12            1500000.0                          USD
# 14693        2016-11-18                  NaN                          NaN
# 15129        2019-06-13            7000000.0                          USD
# 16175        2019-07-01             186600.0                          USD
# 19236        2020-03-05            8300000.0                          USD
# 19591        2017-11-01             200000.0                          USD
# 20368        2018-05-18            7500000.0                          SEK
# 20861        2018-03-01            2000000.0                          USD
#
#        Last Funding Amount Currency (in USD) Number of Employees  \
# 2046                                     NaN                 NaN
# 2194                                 22218.0                 NaN
# 4295                                     NaN                 NaN
# 13081                              4258652.0             101-250
# 13314                              1500000.0                 NaN
# 14693                                    NaN                 NaN
# 15129                              7000000.0                 NaN
# 16175                               186600.0                 NaN
# 19236                              8300000.0                 NaN
# 19591                               200000.0                 NaN
# 20368                               856868.0                 NaN
# 20861                              2000000.0                 NaN
#
#        Total Funding Amount Currency (in USD)  Number of Funding Rounds  \
# 2046                               35750000.0                       5.0
# 2194                                  22218.0                       1.0
# 4295                                      NaN                       1.0
# 13081                               4258652.0                       1.0
# 13314                               2500000.0                       2.0
# 14693                                     NaN                       1.0
# 15129                               9000000.0                       3.0
# 16175                               1536600.0                       4.0
# 19236                              22000000.0                       5.0
# 19591                                200000.0                       1.0
# 20368                                856868.0                       1.0
# 20861                               2000000.0                       1.0
#
#       Acquisition Status Acquired by  Number of Acquisitions  \
# 2046                 NaN         NaN                     NaN
# 2194                 NaN         NaN                     NaN
# 4295                 NaN         NaN                     NaN
# 13081                NaN         NaN                     NaN
# 13314                NaN         NaN                     NaN
# 14693                NaN         NaN                     NaN
# 15129                NaN         NaN                     NaN
# 16175                NaN         NaN                     NaN
# 19236                NaN         NaN                     NaN
# 19591                NaN         NaN                     NaN
# 20368                NaN         NaN                     NaN
# 20861                NaN         NaN                     NaN
#
#        Acquisition Price Currency (in USD)  Number of Founders Company Type  \
# 2046                                   NaN                 2.0   For Profit
# 2194                                   NaN                 1.0   For Profit
# 4295                                   NaN                 1.0   For Profit
# 13081                                  NaN                 1.0   For Profit
# 13314                                  NaN                 1.0   For Profit
# 14693                                  NaN                 1.0   For Profit
# 15129                                  NaN                 3.0   For Profit
# 16175                                  NaN                 3.0   For Profit
# 19236                                  NaN                 2.0   For Profit
# 19591                                  NaN                 3.0   For Profit
# 20368                                  NaN                 3.0          NaN
# 20861                                  NaN                 1.0   For Profit
#
#       Founded Date Funding Status Acquisition Type Announced Date  \
# 2046    2015-01-01           Seed              NaN            NaT
# 2194    2015-01-01           Seed              NaN            NaT
# 4295    2015-03-15           Seed              NaN            NaT
# 13081   2016-01-01           Seed              NaN            NaT
# 13314   2016-03-01           Seed              NaN            NaT
# 14693   2016-06-29           Seed              NaN            NaT
# 15129   2016-08-26           Seed              NaN            NaT
# 16175   2016-12-01           Seed              NaN            NaT
# 19236   2017-07-28           Seed              NaN            NaT
# 19591   2017-10-17           Seed              NaN            NaT
# 20368   2018-01-01           Seed              NaN            NaT
# 20861   2018-03-01           Seed              NaN            NaT
#
#       Estimated Revenue Range
# 2046               10M to 50M
# 2194               10M to 50M
# 4295               10M to 50M
# 13081              10M to 50M
# 13314              10M to 50M
# 14693              10M to 50M
# 15129              10M to 50M
# 16175              10M to 50M
# 19236              10M to 50M
# 19591              10M to 50M
# 20368              10M to 50M
# 20861              10M to 50M

# %% [markdown]
# ## Total Number of Funding Rounds to the Total Amount Raised

# %%
# First we can replace all values that were empty win NaN using np.nan
clean_data['Number of Employees'].replace('', np.nan, inplace=True)
# Then we drop all values in the specified column using .dropna()
clean_num_employees = cleaned_data.dropna(subset=['Number of Employees'])
#clean_num_employees.head(100)




num_of_founders = final_num_founders['Number of Employees'].value_counts()
plt.figure(figsize=(7, 6))
ax = num_of_founders.plot(kind='bar', rot=0, color="b")
ax.set_title("Bar Graph of Number of Employees", y = 1)
ax.set_xlabel('Number of Employees')
plt.xticks(rotation=90)
ax.set_ylabel('Frequency')
#ax.set_xticklabels(('Male', 'Female'))

for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2
    space = 1
    label = "{:.0f}".format(y_value)
    ax.annotate(label, (x_value, y_value), xytext=(0, space), textcoords="offset points", ha='center', va='bottom')
plt.show()
